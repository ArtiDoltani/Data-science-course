# %% [markdown]
# # Assignment # 03

# %% [markdown]
# ### 1. Create a new column in the provided dataset. Column name should be num_of_cast. You have to append or add a column in the dataset which contains the total number of cast in that particular movie or Tv-Show.

# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("netflix_data.csv")
data.head(n=13)
# Out:
#    show_id     type  title              director  \
# 0       s1  TV Show     3%                   NaN
# 1       s2    Movie   7:19     Jorge Michel Grau
# 2       s3    Movie  23:59          Gilbert Chan
# 3       s4    Movie      9           Shane Acker
# 4       s5    Movie     21        Robert Luketic
# 5       s6  TV Show     46           Serdar Akar
# 6       s7    Movie    122       Yasir Al Yasiri
# 7       s8    Movie    187        Kevin Reynolds
# 8       s9    Movie    706         Shravan Kumar
# 9      s10    Movie   1920          Vikram Bhatt
# 10     s11    Movie   1922          Zak Hilditch
# 11     s12  TV Show   1983                   NaN
# 12     s13  TV Show   1994  Diego Enrique Osorno
#
#                                                  cast        country  \
# 0   João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1   Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# ...

# %%
data.loc[1,"cast"]
# Out:
# 'Demián Bichir, Héctor Bonilla, Oscar Serrano, Azalia Ortiz, Octavio Michel, Carmen Beato'

# %%
# Replaced NAN with some value in cast column
#data.cast=data.cast.fillna(" Oscar Serrano, Azalia Ortiz, Octavio Michel")

# %%
data["cast"].fillna("Oscar Serrano, Azalia Ortiz, Octavio Michel", inplace = True)

# %%
data.head(n=13)
# Out:
#    show_id     type  title              director  \
# 0       s1  TV Show     3%                   NaN
# 1       s2    Movie   7:19     Jorge Michel Grau
# 2       s3    Movie  23:59          Gilbert Chan
# 3       s4    Movie      9           Shane Acker
# 4       s5    Movie     21        Robert Luketic
# 5       s6  TV Show     46           Serdar Akar
# 6       s7    Movie    122       Yasir Al Yasiri
# 7       s8    Movie    187        Kevin Reynolds
# 8       s9    Movie    706         Shravan Kumar
# 9      s10    Movie   1920          Vikram Bhatt
# 10     s11    Movie   1922          Zak Hilditch
# 11     s12  TV Show   1983                   NaN
# 12     s13  TV Show   1994  Diego Enrique Osorno
#
#                                                  cast        country  \
# 0   João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1   Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# ...

# %%
arr=data.loc[:,"cast"].split(", ")
#len(arr)

# %%
len(arr)
# Out:
# 159

# %%
# Adding column at index 5
data.insert(5,"num_of_cast",len(arr))

# %%
data.head(n=13)
# Out:
#    show_id     type  title              director  \
# 0       s1  TV Show     3%                   NaN
# 1       s2    Movie   7:19     Jorge Michel Grau
# 2       s3    Movie  23:59          Gilbert Chan
# 3       s4    Movie      9           Shane Acker
# 4       s5    Movie     21        Robert Luketic
# 5       s6  TV Show     46           Serdar Akar
# 6       s7    Movie    122       Yasir Al Yasiri
# 7       s8    Movie    187        Kevin Reynolds
# 8       s9    Movie    706         Shravan Kumar
# 9      s10    Movie   1920          Vikram Bhatt
# 10     s11    Movie   1922          Zak Hilditch
# 11     s12  TV Show   1983                   NaN
# 12     s13  TV Show   1994  Diego Enrique Osorno
#
#                                                  cast  num_of_cast  \
# 0   João Miguel, Bianca Comparato, Michel Gomes, R...            6
# 1   Demián Bichir, Héctor Bonilla, Oscar Serrano, ...            6
# 2   Tedd Chan, Stella Chung, Henley Hii, Lawrence ...            6
# ...
